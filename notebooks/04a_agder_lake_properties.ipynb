# %%
import pandas as pd
from tabula import read_pdf

# %% [markdown]
# # Extract properties for Agder lakes from PDF
#
# Martin Hagen Ring has sent data describing the amount of lime (in tonnes) added to various lakes in Agder since the 1960s. He has also provided a PDF containing properties (volume, residence time etc.) for some of these lakes. See e-mail received 22.01.2024 for details.
#
# This notebook extracts the lake properties from the PDF and saves them to Excel, along with the dataet describing lime amounts added.

# %%
# Read PDF data table
lake_df = read_pdf("../data/Dybdekart_samlet.pdf", pages=1)[0]
lake_df = lake_df.dropna(axis=1, how="all")
lake_df.columns = [
    "lake",
    "kommune",
    "nve_nr",
    "digitalised",
    "map_sheet:",
    "utm",
    "depth_map",
    "echo_sounder",
    "catch_area_m2",
    "ann_runoff_m",
    "ann_runoff_m3",
    "mean_q_m3ps",
    "lake_area_m2",
    "max_depth_m",
    "mean_depth_m",
    "volume_m3",
    "tau_years",
    "comment",
]

# Deal with strange values saved to PDF from Excel
lake_df = lake_df.query("tau_years != '#DIV/0!'")
lake_df = lake_df.applymap(
    lambda x: str(x).replace(",", ".") if isinstance(x, str) else x
)
lake_df = lake_df.applymap(
    lambda x: str(x).replace(" ", "") if isinstance(x, str) else x
)
for col in lake_df.columns:
    try:
        lake_df[col] = lake_df[col].astype(float)
    except ValueError:
        pass

# Just lakes with valid NVE ID and tau > 0
lake_df.dropna(subset=["nve_nr", "tau_years"], inplace=True)
lake_df = lake_df.query("tau_years > 0").reset_index(drop=True)

# Tidy
cols = [
    "lake",
    "kommune",
    "nve_nr",
    "utm",
    "catch_area_m2",
    "ann_runoff_m",
    "ann_runoff_m3",
    "mean_q_m3ps",
    "lake_area_m2",
    "max_depth_m",
    "mean_depth_m",
    "volume_m3",
    "tau_years",
]
lake_df = lake_df[cols]
lake_df
# Out:
#                     lake       kommune   nve_nr       utm  catch_area_m2  \
# 0              BEGERVANN      BIRKENES  10772.0  616792.0      4100000.0
# 1          BELLANDSTJERN      BIRKENES  10539.0  472860.0      2000000.0
# 2               BJORVAtN  EVJE/HORNNES  10217.0  348940.0      5650000.0
# 3              FLEKEVATN       FROLAND  10164.0  601951.0      1400000.0
# 4               FØREVANN       FROLAND   1335.0  483982.0     10700000.0
# 5               GANGVATN  GRIMST/AREND  10636.0  712827.0      2250000.0
# 6                GJEVDEN          ÅMLI   7863.0  526360.0     13500000.0
# 7             HAUKOMVATN      BIRKENES   1334.0       NaN     18500000.0
# 8                 HÅVATN       FROLAND  10313.0  722906.0      3000000.0
# 9           HUNSDALSVANN      GRIMSTAD  10711.0  698808.0      2500000.0
# 10         KALLBERGSVANN     VEGÅRSHEI   8980.0  960167.0     12000000.0
# 11           KILANDSVANN      GRIMSTAD  10860.0  650745.0     50000000.0
# 12             KLEIVVANN      GJERSTAD   8330.0  945274.0     10600000.0
# 13          KOLLANDSVANN      GRIMSTAD  10722.0  666803.0      1500000.0
# 14          KYLLANDSVANN      BIRKENES  10610.0  569844.0      1800000.0
# 15              LANGVANN     LILLESAND  10908.0  608732.0      1400000.0
# 16             MJONEVATN          ÅMLI   9407.0  767083.0      2500000.0
# 17               MJÅVANN      GJERSTAD   8237.0  956304.0      3400000.0
# 18               MJÅVATN         VALLE   1085.0  264496.0     12900000.0
# 19            MØRLØSVANN       FROLAND  10718.0  742814.0      3800000.0
# 20                  OGGE       IVELAND   1322.0  514823.0    250000000.0
# 21             OKSETJØNN         VALLE  15041.0  252512.0      1700000.0
# 22  ROSALVATN/VIERLIVATN     VEGÅRSHEI   9476.0  964068.0      5200000.0
# 23              ROSÆVANN       FROLAND  10210.0  695931.0      2600000.0
# 24               RØYVANN      Gjerstad   8872.0   73183.0       678000.0
# 25          SAURDALSVATN       FROLAND  10080.0  594958.0      3750000.0
# 26               SKJERSÆ       FROLAND  10044.0  664962.0     19000000.0
# 27            SNØLØSVATN      GRIMSTAD  10651.0  700819.0      6000000.0
# 28            STEINSVANN      BIRKENES  10932.0  607711.0      4800000.0
# 29            STEINSVATN     LILLESAND  11304.0  552545.0      3200000.0
# 30           STRONDEVANN       BYGLAND   8195.0  312304.0      2300000.0
# 31        TJØRNSTØYLVATN       BYGLAND   9298.0  356105.0      2220000.0
# 32          TØNNESØLVANN      GRIMSTAD  10807.0  708754.0     11700000.0
# 33               UFSVANN     VEGÅRSHEI   9337.0  801104.0     10000000.0
# 34       VEGÅR.VESTFJORD     VEGÅRSHEI   1258.0  855173.0     62000000.0
# 35            VESTERVANN      BIRKENES  10977.0  595712.0       830000.0
# 36       VESTREGRIMEVANN     LILLESAND  11092.0  701731.0     17000000.0
# 37         VIGELANDSVANN      GRIMSTAD   1294.0  721775.0     35000000.0
# 38              VÅLEVATN     VEGÅRSHEI   9200.0  116792.0      4500000.0
#
#     ann_runoff_m  ann_runoff_m3  mean_q_m3ps  lake_area_m2  max_depth_m  \
# 0           1.00      4100000.0         0.13      760000.0         62.0
# 1           1.00      2000000.0         0.06      185000.0         14.5
# 2           1.20      6780000.0         0.21      420000.0         19.0
# 3           1.00      1400000.0         0.04      531000.0         12.0
# 4           1.05     11235000.0         0.36     1404000.0         24.0
# 5           1.00      2250000.0         0.07      455000.0         25.0
# 6           1.00     13500000.0         0.43      660000.0         21.0
# 7           1.20     22200000.0         0.70     1480000.0         60.0
# 8           1.00      3000000.0         0.10      725000.0         61.0
# 9           1.00      2500000.0         0.08      360000.0         17.0
# 10          0.95     11400000.0         0.36      570000.0         18.0
# 11          1.00     50000000.0         1.59      701500.0         30.0
# 12          1.00     10600000.0         0.34      518000.0         75.0
# 13          1.00      1500000.0         0.05      210000.0         48.0
# 14          1.00      1800000.0         0.06      230000.0         23.0
# 15          1.00      1400000.0         0.04       85000.0         17.0
# 16          1.00      2500000.0         0.08      550000.0         26.0
# 17          1.00      3400000.0         0.11      230000.0         45.0
# 18          1.10     14190000.0         0.45     1640000.0         75.0
# 19          0.90      3420000.0         0.11      300000.0         33.0
# 20          1.25    312500000.0         9.91     6110000.0         70.0
# 21          1.10      1870000.0         0.06      314000.0         21.0
# 22          0.80      4160000.0         0.13      320000.0         37.0
# 23          1.00      2600000.0         0.08      470000.0         21.0
# 24          0.80       542400.0         0.02      111400.0         35.0
# 25          1.00      3750000.0         0.12      256000.0         34.0
# 26          1.00     19000000.0         0.60     1022000.0         47.0
# 27          1.00      6000000.0         0.19     1275000.0         54.0
# 28          1.00      4800000.0         0.15      665000.0         26.0
# 29          1.00      3200000.0         0.10      145000.0         31.0
# 30          1.00      2300000.0         0.07      243000.0         17.0
# 31          1.20      2664000.0         0.08      318000.0         38.0
# 32          0.90     10530000.0         0.33      793000.0         34.0
# 33          1.00     10000000.0         0.32      425000.0         82.0
# 34          1.00     62000000.0         1.97     6250000.0         66.0
# 35          1.00       830000.0         0.03      134000.0         22.0
# 36          1.00     17000000.0         0.54     1170000.0         56.0
# 37          1.00     35000000.0         1.11     1520000.0         45.0
# 38          1.00      4500000.0         0.14      374000.0         19.0
#
#     mean_depth_m    volume_m3  tau_years
# 0          14.60   11096000.0       2.71
# 1           2.70     499500.0       0.25
# 2           6.26    2629200.0       0.39
# 3           3.50    1858500.0       1.33
# 4           5.95    8353800.0       0.74
# 5           6.55    2980250.0       1.32
# 6           6.70    4422000.0       0.33
# 7          16.90   25012000.0       1.13
# 8          18.40   13340000.0       4.45
# 9           8.00    2880000.0       1.15
# 10          5.10    2907000.0       0.26
# 11          8.60    6032900.0       0.12
# 12         22.20   11499600.0       1.08
# 13         12.70    2667000.0       1.78
# 14          9.00    2070000.0       1.15
# 15          6.24     530400.0       0.38
# 16         10.25    5637500.0       2.26
# 17         14.40    3312000.0       0.97
# 18         19.10   31324000.0       2.21
# 19         12.70    3810000.0       1.11
# 20         14.28   87250800.0       0.28
# 21          5.90    1852600.0       0.99
# 22          7.30    2336000.0       0.56
# 23          4.59    2157300.0       0.83
# 24         11.70    1303380.0       2.40
# 25          6.45    1651200.0       0.44
# 26         14.90   15227800.0       0.80
# 27         21.30   27157500.0       4.53
# 28          8.70    5785500.0       1.21
# 29         10.10    1464500.0       0.46
# 30          6.20    1506600.0       0.66
# 31         12.40    3943200.0       1.48
# 32          9.96    7898280.0       0.75
# 33         25.30   10752500.0       1.08
# 34         17.97  112312500.0       1.81
# 35          4.90     656600.0       0.79
# 36         20.90   24453000.0       1.44
# 37         16.40   24928000.0       0.71
# 38          6.40    2400000.0       0.53

# %%
# Read liming data
lime_df = pd.read_excel("../data/agder_lime_added_raw.xlsx", sheet_name="data")
lime_df.head()
# Out:
#     lnr                 forening             name     kommune  year  tonnes  \
# 0   905  Hægebostad og Eiken JFF     Gletnevatnet  Hægebostad  1994     0.0
# 1  1690            Vegårshei JFF  Kallbergsvatnet  Vegårdshei  1985     0.0
# 2  1691            Vegårshei JFF  Kallbergsvatnet  Vegårdshei  1986     0.0
# 3  1692            Vegårshei JFF  Kallbergsvatnet  Vegårdshei  1987     0.0
# 4  1693            Vegårshei JFF  Kallbergsvatnet  Vegårdshei  1988     0.0
#
#   method          lime  nve_nr  utm33_north  utm33_east      lat      lon
# 0    Båt  Kalksteinmel    1234      6502418       49049  58.4286  7.26775
# 1    Båt  Kalksteinmel    8980      6532208      148917  58.7863  8.92145
# 2    Båt  Kalksteinmel    8980      6532208      148917  58.7863  8.92145
# 3    Båt  Kalksteinmel    8980      6532208      148917  58.7863  8.92145
# 4    Båt  Kalksteinmel    8980      6532208      148917  58.7863  8.92145

# %%
# Filter lime data and lake data to only include lakes that match
nve_ids = list(
    set(lake_df["nve_nr"].astype(int).tolist()).intersection(
        set(lime_df["nve_nr"].astype(int).tolist())
    )
)
lake_df = lake_df.query("nve_nr in @nve_ids").reset_index(drop=True)
lime_df = lime_df.query("nve_nr in @nve_ids").reset_index(drop=True)

# Save
with pd.ExcelWriter('../data/agder_liming_data_tidy.xlsx') as writer:
    lake_df.to_excel(writer, sheet_name='lake_props', index=False)
    lime_df.to_excel(writer, sheet_name='lime_added', index=False)
